# %% [markdown]
# ## Python Mini-Project: Data Clean-Up, Pt. 2
#
# Pay close attention to the prompts to help guide you through this task.

# %%
# Dependencies
import pandas as pd
import os

# %%
# load CSV
csvpath = os.path.join("Resources", "2016-FCC-New-Coders-Survey-Data.csv")

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
# You may need to encode this file
codersDF = pd.read_csv(csvpath, encoding='iso-8859-1', low_memory=False)
codersDF
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                    NaN                NaN          NaN                 NaN
# 1                    NaN                NaN          NaN                 NaN
# 2                    NaN                NaN          NaN                 NaN
# 3                    NaN                NaN          NaN                 NaN
# 4                    NaN                NaN          NaN                 NaN
# ...                  ...                ...          ...                 ...
# 15615                NaN                NaN          NaN                 NaN
# 15616                NaN                NaN          NaN                 NaN
# 15617                NaN                NaN          NaN                 NaN
# 15618                NaN                NaN          NaN                 NaN
# 15619                NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                    NaN             NaN  ...               NaN
# 1                    NaN             NaN  ...               NaN
# 2                    NaN             NaN  ...               NaN
# 3                    NaN             NaN  ...               NaN
# 4                    NaN             NaN  ...               NaN
# ...                  ...             ...  ...               ...
# 15615                NaN             NaN  ...               NaN
# 15616                NaN             NaN  ...               NaN
# 15617                NaN             NaN  ...               NaN
# 15618                NaN             NaN  ...               NaN
# 15619                NaN             NaN  ...               NaN
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 0                        NaN                NaN              NaN
# 1                        NaN                NaN              NaN
# 2                        NaN                NaN              NaN
# 3                        NaN                NaN              NaN
# 4                        NaN                NaN              NaN
# ...                      ...                ...              ...
# 15615                    NaN                NaN              NaN
# 15616                    NaN                1.0              NaN
# 15617                    NaN                NaN              NaN
# 15618                    NaN                NaN              NaN
# 15619                    NaN                NaN              NaN
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 0                NaN                NaN              NaN
# 1                1.0                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN
# ...              ...                ...              ...
# 15615            1.0                NaN              NaN
# 15616            NaN                NaN              NaN
# 15617            NaN                NaN              NaN
# 15618            1.0                NaN              NaN
# 15619            NaN                NaN              NaN
#
#                                   SchoolDegree              SchoolMajor  \
# 0               some college credit, no degree                      NaN
# 1               some college credit, no degree                      NaN
# 2      high school diploma or equivalent (GED)                      NaN
# 3                            bachelor's degree  Cinematography And Film
# 4               some college credit, no degree                      NaN
# ...                                        ...                      ...
# 15615                        bachelor's degree                Chemistry
# 15616                        bachelor's degree   Electrical Engineering
# 15617                        bachelor's degree                Chemistry
# 15618       master's degree (non-professional)                     Math
# 15619                        bachelor's degree           Graphic Design
#
#        StudentDebtOwe
# 0             20000.0
# 1                 NaN
# 2                 NaN
# 3              7000.0
# 4                 NaN
# ...               ...
# 15615             NaN
# 15616             NaN
# 15617             NaN
# 15618             NaN
# 15619         40000.0
#
# [15620 rows x 113 columns]

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
# Consider using iloc
codersDFcolumns = codersDF.iloc[:,[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
codersDFcolumns.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# 1             NaN  between 100,000 and 1 million  ...
# 2             NaN            more than 1 million  ...
# 3             NaN            more than 1 million  ...
# 4             NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren  HoursLearning   Income  \
# 0  Employed for wages    male         0.0           30.0  32000.0
# 1  Employed for wages    male         NaN           30.0  15000.0
# 2  Employed for wages    male         NaN           20.0  48000.0
# 3  Employed for wages  female         NaN           20.0  43000.0
# 4  Employed for wages  female         NaN           25.0   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Change reading 0 and 1 to No and Yes, respectively
replacementvalues = {0.0:"No",1.0:"Yes"}
codersDFcolumns = codersDFcolumns.replace({"AttendedBootcamp":replacementvalues,
                         "BootcampFinish":replacementvalues,
                         "BootcampFullJobAfter":replacementvalues,
                         "BootcampRecommend":replacementvalues,
                         "HasChildren":replacementvalues,
                         "BootcampLoanYesNo":replacementvalues
                        })
                         
codersDFcolumns.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# 1             NaN  between 100,000 and 1 million  ...
# 2             NaN            more than 1 million  ...
# 3             NaN            more than 1 million  ...
# 4             NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren HoursLearning   Income  \
# 0  Employed for wages    male          No          30.0  32000.0
# 1  Employed for wages    male         NaN          30.0  15000.0
# 2  Employed for wages    male         NaN          20.0  48000.0
# 3  Employed for wages  female         NaN          20.0  43000.0
# 4  Employed for wages  female         NaN          25.0   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Extract rows for only those who attended a bootcamp
attendeesDF = codersDFcolumns[codersDFcolumns["AttendedBootcamp"] == "Yes"]
attendeesDF
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32.0              Yes            Yes                   No
# 97     26.0              Yes            Yes                  Yes
# 130    41.0              Yes            Yes                  Yes
# 159    26.0              Yes            Yes                   No
# 188    24.0              Yes             No                  NaN
# ...     ...              ...            ...                  ...
# 15539  39.0              Yes            Yes                  Yes
# 15540  24.0              Yes            Yes                  Yes
# 15541  23.0              Yes            Yes                  Yes
# 15593  29.0              Yes             No                  NaN
# 15600  28.0              Yes            Yes                  Yes
#
#       BootcampLoanYesNo              BootcampName  BootcampPostSalary  \
# 93                   No            Codify Academy                 NaN
# 97                   No            DaVinci Coders             45000.0
# 130                 Yes             Coder Foundry             75000.0
# 159                  No          General Assembly                 NaN
# 188                 Yes                       NaN                 NaN
# ...                 ...                       ...                 ...
# 15539               Yes                 CodeaCamp                 NaN
# 15540               Yes  Anyone Can Learn To Code                 NaN
# 15541                No                 CodeaCamp             21600.0
# 15593                No            Camp Code Away                 NaN
# 15600                No                  Epicodus             36000.0
#
#       BootcampRecommend  ChildrenNumber                 CityPopulation  ...  \
# 93                   No             NaN  between 100,000 and 1 million  ...
# 97                   No             NaN            more than 1 million  ...
# 130                 Yes             3.0              less than 100,000  ...
# 159                  No             NaN  between 100,000 and 1 million  ...
# 188                  No             NaN  between 100,000 and 1 million  ...
# ...                 ...             ...                            ...  ...
# 15539               Yes             NaN            more than 1 million  ...
# 15540                No             NaN            more than 1 million  ...
# 15541               Yes             NaN            more than 1 million  ...
# 15593                No             NaN            more than 1 million  ...
# 15600               Yes             NaN  between 100,000 and 1 million  ...
#
#                     CountryLive                        EmploymentField  \
# 93     United States of America  arts, entertainment, sports, or media
# 97     United States of America                   software development
# 130    United States of America                   software development
# 159    United States of America                                    NaN
# 188                      Canada                                    NaN
# ...                         ...                                    ...
# 15539                    Mexico                                    NaN
# 15540                     Kenya  arts, entertainment, sports, or media
# 15541                    Mexico            software development and IT
# 15593                     India            software development and IT
# 15600  United States of America            software development and IT
#
#                            EmploymentStatus  Gender HasChildren HoursLearning  \
# 93             Self-employed business owner    male         NaN          20.0
# 97                       Employed for wages    male          No          10.0
# 130                      Employed for wages    male         Yes          30.0
# 159    Not working and not looking for work  female         NaN          30.0
# 188        Not working but looking for work  female         NaN          60.0
# ...                                     ...     ...         ...           ...
# 15539              Self-employed freelancer  female         NaN          15.0
# 15540                    Employed for wages  female         NaN          10.0
# 15541                    Employed for wages    male         NaN          24.0
# 15593                    Employed for wages  female          No           5.0
# 15600                    Employed for wages  female         NaN           8.0
#
#          Income           JobRoleInterest                        SchoolDegree  \
# 93      67000.0                       NaN                   bachelor's degree
# 97      40000.0                       NaN  master's degree (non-professional)
# 130     75000.0                       NaN      some college credit, no degree
# 159         NaN  Full-Stack Web Developer      some college credit, no degree
# 188         NaN                       NaN      some college credit, no degree
# ...         ...                       ...                                 ...
# 15539   36000.0  Full-Stack Web Developer      some college credit, no degree
# 15540   16800.0                       NaN                   bachelor's degree
# 15541   42000.0                       NaN  master's degree (non-professional)
# 15593  200000.0                       NaN                   bachelor's degree
# 15600  200000.0                       NaN                   bachelor's degree
#
#                                              SchoolMajor
# 93                                               Biology
# 97                                                 Music
# 130                                                  NaN
# 159                                                  NaN
# 188                                                  NaN
# ...                                                  ...
# 15539                                                NaN
# 15540  Computer Systems Networking and Telecommunicat...
# 15541                      Computer Software Engineering
# 15593                                         Accounting
# 15600                                          Marketing
#
# [953 rows x 21 columns]

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
# Create a DataFrame from using value_counts
valuecountsframe = attendeesDF["BootcampName"].value_counts().to_frame()
valuecountsframe = valuecountsframe.rename(columns={"BootcampName":"Enrollees"})
valuecountsframe
# Out:
#                        Enrollees
# General Assembly              90
# Flatiron School               54
# Dev Bootcamp                  48
# The Iron Yard                 40
# Prime Digital Academy         30
# ...                          ...
# Founders & Coders              1
# Code Institute                 1
# SeedPaths                      1
# Astro Code School              1
# Base10 Academy                 1
#
# [128 rows x 1 columns]

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommendDFseries = attendeesDF[(attendeesDF["BootcampRecommend"] == "Yes") & (attendeesDF["BootcampName"] != 'Free Code Camp is not a bootcamp - please scroll up and change answer to "no"')]
recommendDF = recommendDFseries["BootcampName"].value_counts().to_frame()
recommendDF = recommendDF.rename(columns={"BootcampName":"Recommenders"})
recommendDF.head(15)
# Out:
#                                 Recommenders
# General Assembly                          70
# Flatiron School                           50
# Dev Bootcamp                              41
# The Iron Yard                             31
# Hack Reactor                              27
# Turing                                    26
# Prime Digital Academy                     25
# App Academy                               20
# Hackbright Academy                        19
# MakerSquare                               18
# Code Fellows                              15
# New York Code + Design Academy            14
# The Firehose Project                      13
# Dev Academy                               13
# Makers Academy                            12

# %%
# Merge the two created data frames on the name of tbe bootcamp
mergedDF = pd.merge(recommendDF, valuecountsframe, how='left', left_index=True, right_index=True)
mergedDF.head(15)
# Out:
#                                 Recommenders  Enrollees
# General Assembly                          70         90
# Flatiron School                           50         54
# Dev Bootcamp                              41         48
# The Iron Yard                             31         40
# Hack Reactor                              27         29
# Turing                                    26         27
# Prime Digital Academy                     25         30
# App Academy                               20         22
# Hackbright Academy                        19         22
# MakerSquare                               18         20
# Code Fellows                              15         21
# New York Code + Design Academy            14         20
# The Firehose Project                      13         16
# Dev Academy                               13         13
# Makers Academy                            12         12

# %%
# Merge the two created data frames on the name of tbe bootcamp

# %%
# Calculate percentage of each bootcamp's students who are recommenders
# Think of what should be the numerator and the demoninator

# Sort results in descending order

# Format for percentages

mergedDF["% Recommended"] = mergedDF["Recommenders"] / mergedDF["Enrollees"]
mergedDF = mergedDF.sort_values(["% Recommended"], ascending=False)
mergedDF["% Recommended"] = mergedDF["% Recommended"].map("{:.2%}".format)
mergedDF.head(90)
# Out:
#                      Recommenders  Enrollees % Recommended
# Operation Spark                 1          1       100.00%
# Founders & Coders               1          1       100.00%
# DigitalCrafts                   2          2       100.00%
# Base10 Academy                  1          1       100.00%
# Academia de CÃ³digo             4          4       100.00%
# ...                           ...        ...           ...
# Coding Dojo                    11         18        61.11%
# Codeup                          6         10        60.00%
# Bitmaker Labs                   3          5        60.00%
# CodeCore Bootcamp               3          5        60.00%
# 10x.org.il                      3          5        60.00%
#
# [90 rows x 3 columns]

# %%
# Export to excel and remove index
mergedDF.to_excel("data-clean2.xlsx",index=False)
